# %% [markdown]
# # Protocol Sweep And Results
#
# Inspect the CSV outputs generated by `python main.py`.

# %%
import pandas as pd

metrics = pd.read_csv('../outputs/metrics/metrics_summary.csv')
sweep = pd.read_csv('../outputs/metrics/parameter_sweep_results.csv')
metrics.head(), sweep.head()
