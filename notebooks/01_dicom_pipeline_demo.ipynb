# %% [markdown]
# # DICOM Pipeline Demo
#
# Run the full MRI metal artefact and relative SAR pipeline from the repository root.

# %%
from main import run_pipeline

result = run_pipeline()
result['sar_summary']
